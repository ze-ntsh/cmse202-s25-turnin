# %% [markdown]
# # Homework Assignment 2
# ## Modeling planets' orbits
#
# ### (Notebook 1 of 2)

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Nitish Maindoliya</p>
# ### <p style="text-align: right;"> &#9989; _ze-ntsh_</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## Table of contents
#
# 0. [Pre Assignment Survey](#ofhrs) (0 points + 1 git)
#
# 1. [Planet orbits and migration](#part1) (14 points + 1 git)
#
# 2. [Modeling planet migration](#part2) (33 points + 1 git)

# %% [markdown]
# ## Learning Goals
#
# By the end of this assignment, you should be able to:
#
# - Define planet migration types
# - Compare orbit shapes, based on the mass of the planet/the star, the radius of the orbit, and the eccentricity
# - Be able to find the orbital period from orbit properties
# - Be able to write methods and attributes of a class, based on the description of the final needed result
# - Be able to define agents using classes in Python and interactions between them using methods of Python classes.
# - Describe an agent-based model that accurately presents the properties of a planetary system.
# - Implement the evolution of the agent-based model by correctly applying the rules for the model and updating the state of the agents in the model.
# - Be able to identify needed forces and their effect on modeling planet migration.
# - Be able to visualize and describe the results of planetary migration simulation.
#
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# The assignment is split into two notebooks:
# - Notebook 1 of 2 is worth **14 + 33 + 3 = 51 points**
# - Notebook 2 of 2 is worth **1+ 42 + 1 = 44 points**
# for a total of **95 points**. Point values for each part are included in the section headers and question prompts.
#
# **This assignment is due at 11:59 pm on Friday, March 21st.** It should be uploaded into the "Homework Assignments" submission folder for Homework #2 on D2L.  Submission instructions can be found at the end of the notebook. **You must also fill out a survey regarding this assignment.** The link to this survey can also be found at the end of the notebook.

# %% [markdown]
# ---
# <a id="ofhrs"></a>
# [Back to ToC](#toc)
#
# ## Pre-assignment Survey
#
# Please fill out the pre-assignment survey [**here**](https://forms.office.com/r/qLEDb8Fhtr).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## &#128721; STOP
# **Pause to commit your changes to your Git repository! (1 points)**
#
# Create a ```hw-02``` folder in your ```cmse202-s25-turnin``` repo. Take a moment to save your notebook, add and commit the changes to your Git repository using the commit message "**Initial commit of HW 2**", no need to push the changes to GitHub yet, but you can if you want.

# %% [markdown]
# ---
# <a id=part1></a>
# [Back to ToC](#toc)
#
# ## Part 1: Planet orbits and migration types (14 Points)
#
# ✅ **Do this:** Watch these 2 videos and answer the questions below.
#
# - [Orbit types](https://www.youtube.com/watch?v=pRvVK2m_wGE)
# - [Planetary Migration in a Disk](https://www.youtube.com/watch?v=BGPBNeTFXZk) -

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('pRvVK2m_wGE', width=800, height=400)

# %%
YouTubeVideo('BGPBNeTFXZk', width=800, height=400, end=260)

# %% [markdown]
# ✅ **Question 1.1 (1 point):** What shape is Earth's orbit?

# %% [markdown]
# - The shape of Earth's orbit is an ellipse

# %% [markdown]
# ✅ **Question 1.2 (3 points):** How many types of orbit shapes did the 1st video mention? Which shape is more common for satellites and planets in our Solar system?

# %% [markdown]
# - The first video mentioned 4 types of orbit shapes: circular, elliptical, parabolic, and hyperbolic.
# - The most common shape for satellites and planets in our Solar system is elliptical.

# %% [markdown]
# ✅ **Question 1.3 (1 point):** How many types of migration did the 2nd video mention?

# %% [markdown]
# - The second video mentioned 3 types of migration:
# - Type I migration (migration of low-mass planets)
# - Type II migration (migration of high-mass planets)
# - Type III migration

# %% [markdown]
# ✅ **Question 1.4 (2 points):** We see hot Jupiters (planets the size of Jupiter but hot!) in orbits very, very close to their stars. Because of the temperature in these regions, there is no way that planets the size of Jupiter (300 times Earth's mass and 11 times Earth's radius) could form because the star would just steal all the gas and not let the planet to form. But we still see hot Jupiters in those orbits. How do they end up near their stars?

# %% [markdown]
# - Hot Jupiters end up near their stars due to the process of migration.
# - Type II migration is the process that explains how hot Jupiters end up near their stars. In this process, a planet's gravitational interaction with the disk of gas and dust around a star causes it to migrate inward towards the star.
# - The planet's gravity creates a gap in the disk, and the interaction with the disk's material causes the planet to lose angular momentum, causing it to spiral inward. This process can result in hot Jupiters being found in orbits very close to their stars.

# %% [markdown]
# ## Orbital period
#
# An important parameter for a planet orbiting a star is its orbital period. This is the time it takes for the planet to travel 1 whole orbit. For example, for the Earth the orbital period is 1 year. Using any Large Language Model(LLM), identify how you can find the orbital period from radius/semi-major axis of the orbit. Make sure to ask follow up questions to make sure you get an ***equation*** for orbital period T and radius a (or r). **Use 2 different prompts** and copy and paste both answers in the 2 cells below. Make sure to include a screenshot of the equation you get.

# %% [markdown]
# **Prompt 1:** How can I find the orbital period of a planet orbiting a star, given the radius of the orbit? Please provide an equation for the orbital period T in terms of the radius a (or r) of the orbit.
#
# **Answer 1:**
#
# To find the orbital period \( T \) of a planet orbiting a star, given the radius of the orbit \( a \) (or \( r \)), you can use **Kepler's Third Law**, which relates the orbital period to the semi-major axis of the orbit (which is approximately the radius for a nearly circular orbit).
#
# The formula is:
#
# $$
# T^2 = \frac{4 \pi^2 a^3}{G M}
# $$
#
# Where:
# - \( T \) is the orbital period (in seconds),
# - \( a \) is the semi-major axis of the orbit (in meters),
# - \( G \) is the gravitational constant (\( 6.67430 \times 10^{-11} \, \text{m}^3 \, \text{kg}^{-1} \, \text{s}^{-2} \)),
# - \( M \) is the mass of the star (in kilograms).
#
# To find \( T \), rearrange the equation:
#
# $$
# T = 2 \pi \sqrt{\frac{a^3}{G M}}
# $$
#
# This will give you the orbital period in seconds. You can convert the result to other units, like days, if needed.

# %% [markdown]
# **Prompt 2:** Given the radius of the orbit, how can I find the orbital period of a planet orbiting a star? Please provide an equation for the orbital period T in terms of the radius a (or r) of the orbit.
#
# **Answer 2:**
# To find the orbital period \( T \) of a planet orbiting a star, you can use **Kepler's Third Law of Planetary Motion**. This law relates the orbital period of a planet to the semi-major axis (radius) of its orbit around the star. The equation is:
#
# $$
# T^2 = \frac{4\pi^2}{G(M_\star + M_p)} \, a^3
# $$
#
# Where:
# - \( T \) is the orbital period of the planet,
# - \( a \) is the semi-major axis (radius) of the orbit,
# - \( G \) is the gravitational constant (\( 6.67430 \times 10^{-11} \, \text{m}^3 \, \text{kg}^{-1} \, \text{s}^{-2} \)),
# - \( M_\star \) is the mass of the star,
# - \( M_p \) is the mass of the planet.
#
# If the mass of the planet \( M_p \) is much smaller than the mass of the star \( M_\star \), you can approximate \( M_\star + M_p \approx M_\star \), and the equation simplifies to:
#
# $$
# T^2 = \frac{4\pi^2}{GM_\star} \, a^3
# $$
#
# This is the most commonly used form of Kepler's Third Law for a planet orbiting a star. To solve for \( T \), take the square root of both sides:
#
# $$
# T = 2\pi \sqrt{\frac{a^3}{GM_\star}}
# $$
#
# This gives the orbital period \( T \) in terms of the semi-major axis \( a \) and the mass of the star \( M_\star \).

# %% [markdown]
# ✅ **Question 1.5 (2 points):** Which prompt got you the answer with the equation? Why do you think one prompt was better to use than the other?

# %% [markdown]
# - Both prompts got me the answer with the equation. However, the second prompt was better to use than the first one because it provided a more detailed explanation of Kepler's Third Law and included the mass of the planet in the equation. This additional information is important for understanding the relationship between the orbital period and the mass of both the planet and the star. The second prompt also provided a more comprehensive explanation of the equation, making it easier to understand the relationship between the orbital period and the radius of the orbit.

# %% [markdown]
# The equation that you found is called **Kepler's third law**. Using google or any other search engine, try to find the same equation and verify that GenAI gave you the correct answer.

# %% [markdown]
# ✅ **Task 1.6 (1 point):** Place a screenshot of the same equation from a reliable source below. Include a reference to that source.

# %% [markdown]
# ![Kepler's Third Law](https://wikimedia.org/api/rest_v1/media/math/render/svg/3ae321ec91231d53924aa0408065ed6f8e701e36)
#
# - Source: [Wikipedia](https://en.wikipedia.org/wiki/Orbital_period#Small_body_orbiting_a_central_body)

# %% [markdown]
# ✅ **Question 1.7 (2 points):** Using the equation you found in the previous step answer the following question. Planet 1's orbital radius is 4 times bigger than Planet 2's orbital radius. They are orbiting the same star. Which planet's orbital period will be greater? Explain your reasoning.

# %% [markdown]
# - Planet 1's orbital period will be greater than Planet 2's orbital period. This is because the orbital period \( T \) is proportional to the square root of the semi-major axis \( a \) raised to the power of 3/2, as shown in Kepler's third law: $$ T = 2\pi \sqrt{\frac{a^3}{GM_\star}} $$. Since Planet 1's orbital radius is 4 times bigger than Planet 2's, we can express this as \( a_1 = 4a_2 \).
# - Substituting this into the equation for the orbital period, we get:
#
#     $$ T_1 = 2\pi \sqrt{\frac{(4a_2)^3}{GM_\star}} = 2\pi \sqrt{\frac{64a_2^3}{GM_\star}} = 8T_2 $$
#
# - This shows that Planet 1's orbital period is 8 times greater than Planet 2's orbital period, meaning Planet 1 takes longer to complete one orbit around the star.
# - Therefore, Planet 1's orbital period will be greater than Planet 2's.

# %% [markdown]
# ## Classes
#
#
#
# In Keppler's third law, there is a constant called the gravitation constant and it has the value $G = 6.67 \times 10^{-11} \frac{N m^2}{{kg}^2}$. Because this number is constant it means that conceptually its value makes no difference in the effects gravity has. That is why we will set the value of this constant to 1.
#
#
#
#
#
# ✅ **Do this 1.8 (2 points):** Using the information you found in the previous part, change the class below to calculate the orbital period in the corresponding method of the `Planet` class.
# Make sure to run the cell under the class to make sure your code works correctly. You will get approximately 99.34 as your orbital period if your code is written correctly.

# %%
class Planet:
    """
    A class representing a planet orbiting a star.

    Attributes:
        mass (float): The mass of the planet.
        orbital_radius (float): The distance of the planet from its star.
        star_mass (float): The mass of the star the planet orbits.
    """
    def __init__(self, mass, orbital_radius, star_mass):
        """
        Initialize a Planet instance with mass, orbital radius, and the mass of its star.
        """
        self.mass = mass
        self.orbital_radius = orbital_radius
        self.star_mass = star_mass
        
    def get_orbital_period(self): #add the missing parameters here
        """
        Calculate and return the orbital period of the planet.
        """
        # here you need to use the equation you found that relates orbital period and radius.
        G = 1
        T = 2 * np.pi * np.sqrt(self.orbital_radius**3 / (G * self.star_mass))
        return T

# %%
#test your code by running this cell
planet = Planet(2, 100, 4000)
print("The orbital period of the planet is", planet.get_orbital_period(), "seconds")
# Out:
# The orbital period of the planet is 99.345882657961 seconds

# %% [markdown]
# ---
# ## &#128721; STOP
# **Pause to commit your changes to your Git repository! (1 points)**
#
# Take a moment to save your notebook, commit the changes to your Git repository using the commit message "**Committing Part 1**", no need to push the changes to GitHub yet, but you can if you want.

# %% [markdown]
# ---
#
# <a id=part2></a>
# [Back to ToC](#toc)
#
# ## Part 2. Modeling planet migration using Agent Based Modeling (33 points)
#
# ### Dimensions
#
# We are going to try modeling planet interaction with surrounding material using Agent Based Modeling (ABM). For the sake of this assignment, we will keep our model simple. We will assume several things:
#
# - All orbits are circular.
# - Interactions can only change the radius of the orbit, but NOT the shape!
# - Only forces acting towards the center or outwards from the center *radially* matter! (The vertical force $F_r$ in the sketch below)
#
# These assumptions let us look at our system as 2 dimensional BUT only care about *radial* forces, aka forces acting along the radius of the orbit.

# %% [markdown]
# ![image](https://www.ux1.eiu.edu/~cfadd/1350/06CirMtn/Images/NetForce.jpg)

# %% [markdown]
# ✅ **Do this 2.1: (1 points)** For the pictures below write down the dimensions of the system.

# %% [markdown]
# **Picture 1**

# %%
from IPython.display import Image 
  
# get the image 
Image(url="https://raw.githubusercontent.com/sonachitchyan/abm_images/main/system1.png", width=600, height=300)
# Out:
# <img src="https://raw.githubusercontent.com/sonachitchyan/abm_images/main/system1.png" width="600" height="300"/>

# %% [markdown]
# It's a 2D system
# - The view is from the side, so we can see the radius of the orbit of th the two planets around the star.
# - If we view the system from above, we can see the 2D system.
# - x: from -1.5 to 1.5
# - y: from -0.25 to 0.25

# %% [markdown]
# **Picture 2**

# %%
from IPython.display import Image 
  
# get the image 
Image(url="https://raw.githubusercontent.com/sonachitchyan/abm_images/main/system2.png")
# Out:
# <img src="https://raw.githubusercontent.com/sonachitchyan/abm_images/main/system2.png"/>

# %% [markdown]
# This is a 3D system.
# - One of the planets orbit seems to be an oval but since that is not possible according to our assumptions, the view is flattened to the xy plane and in actuality the orbit is circular. The planet is in a 3D system.
# - The view is flattened to the xy plane.
# - x from -3 to 1
# - y from -1 to 1.5

# %% [markdown]
# ### Model Set-up

# %% [markdown]
# ✅ **Question 2.2 (1 points):** What are the agents of the model in this case?

# %% [markdown]
# - The agents of the model in this case are the planets and the surrounding material (gas and dust) in the protoplanetary disk. The planets interact with the disk material, which affects their orbits and migration.

# %% [markdown]
# ✅ **Question 2.3 (2 points):** How many different classes do we need to model this system? Take into account the agents and the system that we need to run the simulation.

# %% [markdown]
# - We need at least 2 different classes to model this system:
#     - A class for the planets, which will represent the agents that interact with the disk material.
#     - A class for the disk material, which will represent the surrounding environment that affects the planets' orbits and migration.

# %% [markdown]
# ## Modeling a system of 2 planets around a star

# %% [markdown]
# If we have a system of 2 planets orbiting a star, these planets interact with each other gravitationally. This force is proportional to the planets' masses (bigger mass -> stronger force/interaction) and inversely proportional to the distance between the planets (bigger distance -> weaker force/interaction). If this force is substantial, it can move the planets from their initial orbits, even make them collide in extreme cases! To make sense of how this happens, we can start from a simplified model of 2 planets orbiting the same star. In this part you will create and run that model, plot how the radius from the host star changes for each planet.

# %% [markdown]
# ✅ **Question 2.4 (4 points):** Add docstrings to the methods below. You should include a description of what the method does, a description of parameters and and what the method returns.

# %%
def calculate_forces(planet1, planet2):
    ## NOTE: this finds the force planet2 exerts on planet1.
    ## PARAM: planet1: the planet on which the force is exerted.
    ## PARAM: planet2: the planet that exerts the force.
    ## RETURN: the radial force exerted on planet1 by planet2.
    
    force_x = planet2.mass * planet1.mass * (planet2.x - planet1.x) / ((planet2.x - planet1.x)**2 + (planet2.y - planet1.y)**2)**(1.5)
    force_y = planet2.mass * planet1.mass *  (planet2.y - planet1.y) / ((planet2.x - planet1.x)**2 + (planet2.y - planet1.y)**2)**(1.5)
    force_radial = force_x * planet1.x/planet1.radius + force_y * planet1.y/planet1.radius
    return force_radial

def take_step(planet, force, delta_time):
    ##NOTE: this function calculates the step that planet takes in delta_t time of the simulation and updates the properties of the planet.
    ## There is no return because the changes are done to the planet directly.

    ## PARAM: planet: the planet to be updated.
    ## PARAM: force: the force acting on the planet.
    ## PARAM: delta_time: the time step of the simulation.

    acceleration = force / planet.mass
    radius_change = 0.5 * acceleration * delta_time**2 + planet.velocity_radial * delta_time
    velocity_change = acceleration * delta_time
    planet.radius = planet.radius + radius_change
    planet.x = planet.radius * np.cos(2 * np.pi * delta_time / planet.orbital_period)
    planet.y = planet.radius * np.sin(2 * np.pi * delta_time / planet.orbital_period)
    planet.velocity_radial = planet.velocity_radial + velocity_change
    
    if planet.radius < 0.001:
        planet.radius = 0
        planet.status = "Terminated"
    
    planet.orbital_period = 2 * np.pi * np.sqrt(planet.radius**3/planet.star_mass)

# %% [markdown]
# ✅ **Question 2.5 (3 points):** Describe what the code provided above does. What interaction does it describe? Explain both methods separately.

# %% [markdown]
# - `calculate_forces` function
#     - Calculates the radial force exerted on `planet1` by `planet2`.
#     - **Parameters**:
#         - `planet1`: The planet on which the force is exerted.
#         - `planet2`: The planet that exerts the force.
#     - **Returns**: The radial force exerted on `planet1` by `planet2`.
#     - **How it works**:
#         - Computes the x-component of the force using the masses of the planets and their x-coordinates.
#         - Computes the y-component of the force using the masses of the planets and their y-coordinates.
#         - Calculates the radial force by projecting the x and y components onto the radial direction of `planet1`.
#         - Returns the calculated radial force.
#
# - `take_step` function
#     - Updates the properties of a planet based on the force acting on it and the time step of the simulation.
#
#     - **Parameters**:
#         - `planet`: The planet to be updated.
#         - `force`: The force acting on the planet.
#         - `delta_time`: The time step of the simulation.
#     - **Returns**: None (updates the planet's properties directly).
#     - **How it works**:
#         - Calculates the acceleration of the planet using the force and the planet's mass.
#         - Computes the change in radius using the acceleration, the current radial velocity, and the time step.
#         - Updates the planet's radius by adding the change in radius.
#         - Updates the planet's x and y coordinates based on the new radius and the orbital period.
#         - Updates the planet's radial velocity by adding the change in velocity.
#         - Checks if the planet's radius is below a threshold; if so, sets the planet's status to "Terminated".
#         - Recalculates the planet's orbital period based on the new radius.

# %% [markdown]
# ✅ **Question 2.6 (3 points):** Turn the following pseudo-code into code:

# %% [markdown]
# ```{python, tidy=FALSE, eval=FALSE, highlight=FALSE }
# Class: Planet
#     - Represents a planet orbiting a star.
#
#   Attributes:
#       - mass (float): Set to the mass of the planet.
#       - radius (float): Set to the initial orbital radius of the planet.
#       - star_mass (float): Set to the mass of the star the planet orbits.
#       - orbital_period (float): Compute using Kepler’s third law:
#         orbital_period = 2 * pi * sqrt(radius^3 / star_mass).
#       - velocity_radial (float): Initialize to 0.0.
#       - x (float): Set to radius (initial x-coordinate of the planet).
#       - y (float): Set to 0 (initial y-coordinate of the planet).
#       - status (string): Defaults to "Active". Changes to "Terminated" if the planet falls into the star
#         (radius < sqrt(0.02)).
#   Methods:
#       - __init__:
#         Assigns the default values to the attributes
# ```

# %% [markdown]
# ```{r, tidy=FALSE, eval=FALSE, highlight=FALSE }
# Class: System
#     Represents a planetary system with a central star and two orbiting planets.
#
# Attributes:
#     - star_mass (float): Set to the mass of the central star.
#     - planet1 (Planet): Set to the first planet in the system.
#     - planet2 (Planet): Set to the second planet in the system.
#     - planet1_pos (list): Initialize as a list of lists with first element [0.0, planet1.radius], tracking planet1's position.
#     - planet2_pos (list): Initialize as a list of lists with first element [0.0, planet2.radius], tracking planet2's position.
#
# Methods:
#     - __init__:
#         Assigns the default values to the attributes.
#     - evolve(time):
#         Simulate the evolution of the system over a given time.
#         - Initialize:
#             - t (float): Set to 0.0.
#             - delta_time (float): Set to planet1.orbital_period / 5.
#         - While t < time:
#             - Initialize:
#                 - total_force_planet1 (float): Set to 0.0.
#                 - total_force_planet2 (float): Set to 0.0.
#             - If both planets are "Active" and their squared distance >= 0.02:
#                 - Compute total_force_planet1 using calculate_forces(planet1, planet2).
#                 - Compute total_force_planet2 using calculate_forces(planet2, planet1).
#                 - Update planet1 position using take_step(planet1, total_force_planet1, delta_time).
#                 - Update planet2 position using take_step(planet2, total_force_planet2, delta_time).
#             - Increment t by delta_time.
#             - Append [t, planet1.radius] to planet1_pos.
#             - Append [t, planet2.radius] to planet2_pos.
#             - If either planet’s status is "Terminated", break the loop.
# ```

# %%
# your code here

class Planet:
    """
    Class: Planet
    - Represents a planet orbiting a star.

    Attributes:
        - mass (float): Set to the mass of the planet.
        - radius (float): Set to the initial orbital radius of the planet.
        - star_mass (float): Set to the mass of the star the planet orbits.
        - orbital_period (float): Compute using Kepler’s third law: 
        orbital_period = 2 * pi * sqrt(radius^3 / star_mass).
        - velocity_radial (float): Initialize to 0.0.
        - x (float): Set to radius (initial x-coordinate of the planet).
        - y (float): Set to 0 (initial y-coordinate of the planet).
        - status (string): Defaults to "Active". Changes to "Terminated" if the planet falls into the star 
        (radius < sqrt(0.02)).
    Methods:
        - __init__: 
            Assigns the default values to the attributes.
    """

    def __init__(self, mass=0, radius=0, star_mass=0):
        self.mass = mass
        self.radius = radius
        self.star_mass = star_mass
        self.orbital_period = 2 * np.pi * np.sqrt(radius**3 / star_mass)
        self.velocity_radial = 0
        self.x = radius
        self.y = 0
        self.status = "Active"


class System:
    def __init__(self, star_mass, planet1, planet2):
        self.star_mass = 0
        self.planet1 = planet1
        self.planet2 = planet2
        self.planet1_pos = [[0.0, planet1.radius]]
        self.planet2_pos = [[0.0, planet2.radius]]

    def evolve(self, time):
        t = 0
        dt = self.planet1.orbital_period / 5
        while t < time:
            total_force_planet1 = 0
            total_force_planet2 = 0

            if (self.planet1.status == "Active" and self.planet2.status == "Active") and (self.planet1.radius**2 + self.planet2.radius**2 >= 0.02):
                total_force_planet1 = calculate_forces(self.planet1, self.planet2)
                total_force_planet2 = calculate_forces(self.planet2, self.planet1)
                take_step(self.planet1, total_force_planet1, dt)
                take_step(self.planet2, total_force_planet2, dt)

            t += dt
            self.planet1_pos.append([t, self.planet1.radius])
            self.planet2_pos.append([t, self.planet2.radius])
            
            if self.planet1.status == "Terminated" or self.planet2.status == "Terminated":
                break

# %% [markdown]
# ✅ **Do this:** Explain what the code above does.

# %% [markdown]
# The code defines two classes, `Planet` and `System`, to model a planetary system with two planets orbiting a star. Here's a detailed explanation of what each part of the code does:
#
# ### Planet Class
# The `Planet` class represents a planet orbiting a star. It has the following attributes and methods:
#
# #### Attributes:
# - `mass`: The mass of the planet.
# - `radius`: The initial orbital radius of the planet.
# - `star_mass`: The mass of the star the planet orbits.
# - `orbital_period`: The orbital period of the planet, calculated using Kepler's third law: \( \text{orbital_period} = 2 \pi \sqrt{\frac{\text{radius}^3}{\text{star_mass}}} \).
# - `velocity_radial`: The radial velocity of the planet, initialized to 0.0.
# - `x`: The initial x-coordinate of the planet, set to the radius.
# - `y`: The initial y-coordinate of the planet, set to 0.
# - `status`: The status of the planet, defaults to "Active". Changes to "Terminated" if the planet falls into the star (radius < sqrt(0.02)).
#
# #### Methods:
# - `__init__`: Initializes a `Planet` instance with the given mass, radius, and star mass. It also calculates the orbital period and sets the initial position and status of the planet.
#
# ### System Class
# The `System` class represents a planetary system with a central star and two orbiting planets. It has the following attributes and methods:
#
# #### Attributes:
# - `star_mass`: The mass of the central star.
# - `planet1`: The first planet in the system.
# - `planet2`: The second planet in the system.
# - `planet1_pos`: A list to track the position of `planet1` over time, initialized with the initial position.
# - `planet2_pos`: A list to track the position of `planet2` over time, initialized with the initial position.
#
# #### Methods:
# - `__init__`: Initializes a `System` instance with the given star mass, and two planets. It also initializes the position tracking lists for both planets.
# - `evolve`: Simulates the evolution of the system over a given time period.
#     - Initializes the simulation time `t` to 0 and the time step `dt` to one-fifth of the orbital period of `planet1`.
#     - In a loop that runs until the specified time is reached:
#         - Initializes the total forces acting on both planets to 0.
#         - If both planets are active and their squared distance is greater than or equal to 0.02:
#             - Calculates the forces exerted by each planet on the other using the `calculate_forces` function.
#             - Updates the positions of both planets using the `take_step` function.
#         - Increments the simulation time `t` by the time step `dt`.
#         - Appends the current time and radius of both planets to their respective position tracking lists.
#         - If either planet's status is "Terminated", breaks the loop.
#
# The code is designed to simulate the interaction between two planets orbiting a star, taking into account the gravitational forces between them. The `evolve` method updates the positions and velocities of the planets over time, and tracks their positions in the `planet1_pos` and `planet2_pos` lists.

# %% [markdown]
# ✅ **Do this:** After defining the `System` class, complete and run the following cell.

# %%
pl1 = Planet(1, 10, 400) # planet with mass 1, radius 10 and star mass 400
pl2 = Planet(1, 20, 400) # planet with mass 1, radius 20 and star mass 400
system = System(400,pl1,pl2) # fill in the needed arguments
system.evolve(2000)

# %% [markdown]
# ### Visualization
#
# ✅ **Question 2.7 (1 point):**  Now, taking the saved positions of our planets, we can track how their orbital radius changes with time. To do that, make a scatter plot of orbital radius vs time for both planets using the attributes of the `system` object. Use different colors and label the lines with "Planet 1" and "Planet 2". You can use GenAI for this part but don't forget to add a reference to your answer.

# %%
# your code here
plt.figure(figsize=(10, 5))
plt.scatter(*zip(*system.planet1_pos), label="Planet 1", s=10)
plt.scatter(*zip(*system.planet2_pos), label="Planet 2", s=10)
plt.legend()
plt.title("Planetary Orbits")
plt.xlabel("Time")
plt.grid()
plt.ylabel("Radius")
# Out:
# Text(0, 0.5, 'Radius')

# %% [markdown]
# ✅ **Question 2.8 (4 points):** Using the plot you made, describe what is happening with the two planets. Is this what you expected to happen?

# %% [markdown]
# - The plot indicates that Planet 1's orbital radius increases over time, while Planet 2's orbital radius decreases.
# - This suggests that the two planets are exchanging angular momentum due to their gravitational interaction.
# - Planet 1 is moving outward, and Planet 2 is moving inward.
# - This behavior aligns with the concept of planetary migration, where interactions between planets or with a disk can cause changes in their orbits.
# - Yes, this is consistent with what I expected based on the principles of gravitational interactions and angular momentum conservation.
# - Around time 50, the these two planets seem to have the been close and sling-shotted each other. Now, they are moving away from each other with planet 1 moving inwards and planet 2 moving outwards.
# - The simulation ends with planet 1 collapsing into the star at around time 60.

# %% [markdown]
# ### Modeling a system of 1 big planet and N small planets around a star

# %% [markdown]
# Now let's extend our model for a system of 1 big planet (by big we mean Jupiter size planet) and a bunch of small planets around it, which will be an approximation for the disk.
#
# Here we will provide the generalized code that runs for a set number of planets.

# %%
class System:
    def __init__(self, star_mass, planet_list):
        # the primaty planet we care about is the first planet in the list
        self.star_mass = star_mass
        
        self.planet_list = planet_list
        
        self.number_of_planets = len(planet_list)
        
        self.plot_positions = [[0.0, planet_list[0].radius]]
    
    def evolve(self, time):
        t = 0.0
        delta_time = self.planet_list[0].orbital_period/5
        while t < time:
            # delta_t = self.planet_list[0].orbital_period/5 ## this is the step that chooses the resolution of our simulation
            total_force_list = np.zeros(self.number_of_planets)
            for i, planet in enumerate(self.planet_list):
                if planet.status == "Active":
                    total_force_radial = 0.0
                    for other_planet in self.planet_list:
                        if other_planet.status == "Active":
                            if other_planet != planet and (other_planet.x - planet.x)**2 + (other_planet.y - planet.y)**2 >= 0.02:
                                total_force_radial += calculate_forces(planet, other_planet)
                    total_force_list[i] = total_force_radial

            for i, planet in enumerate(self.planet_list):
                if planet.status == "Active":
                    take_step(planet, total_force_list[i], delta_time)

            
            for planet in self.planet_list:
                if planet.radius < 0.02:
                    planet.status == "Terminated"
            if self.planet_list[0].status == "Terminated":
                break
            t += delta_time
            self.plot_positions.append([t, self.planet_list[0].radius])

# %% [markdown]
# ✅ **Question 2.9 (4 points):** How is the code above different from what you wrote for a 2 planet system?

# %% [markdown]
# The code above differs from the 2-planet system code in several ways:
#
# 1. **Generalization for Multiple Planets:**
#     - Instead of handling only two planets (`planet1` and `planet2`), this code generalizes the system to handle any number of planets using a list (`planet_list`).
#     - The `planet_list` attribute stores all the planets in the system, and the number of planets is determined dynamically using `len(planet_list)`.
#
# 2. **Force Calculation:**
#     - The code calculates the total radial force acting on each planet by iterating over all other planets in the system. This is done using nested loops, where the outer loop iterates over each planet, and the inner loop iterates over all other planets to compute the forces.
#
# 3. **Dynamic Updates:**
#     - The `evolve` method updates the positions and velocities of all planets in the system, not just two specific planets. This is achieved by iterating over the `planet_list`.
#
# 4. **Termination Condition:**
#     - The simulation checks the status of all planets in the system and terminates the simulation if the primary planet (the first planet in the list) falls into the star (`radius < 0.02`).
#
# 5. **Tracking Positions:**
#     - The `plot_positions` attribute tracks the radius of the primary planet (the first planet in the list) over time, allowing for visualization of its orbital evolution.
#
# Overall, this code is more flexible and scalable, as it can handle systems with any number of planets, whereas the 2-planet system code is limited to exactly two planets.

# %% [markdown]
# ✅ **Question 2.10 (3 points):** Run a simulation for a system of 51 planets orbiting a star with mass 400. The first planet of the list is the *primary* planet with mass 150 at radius 1, and the rest of the planets each have a mass of 0.1 and are evenly placed between 0.01 and 0.7 radii. Run the simulation for time of 10.

# %%
#your code here
planets = [Planet(0.1, np.random.uniform(0.01, 0.7), 400) for _ in range(51)]
planets[0] = Planet(150, 1, 400)

system = System(400, planets)
system.evolve(10)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ✅ **Question 2.11 (1 point):** Make the same visualization for radius vs time for the big planet. You can use GenAI for this part but don't forget to add a reference to your answer.

# %%
#your code here
plt.figure(figsize=(10, 5))
plt.scatter(*zip(*system.plot_positions), label="Planet 1", s=10)
plt.xlabel("Time")
plt.ylabel("Radius")
plt.title("Planetary Orbits")
plt.grid()
plt.show()

# %% [markdown]
# ✅ **Question 2.12 (2 points):** Describe what is happening to the planets' orbits based on the plot you made.

# %% [markdown]
# - The plot indicates that the primary planet's orbital radius decreases over time.
# - This suggests that the primary planet is losing angular momentum, likely due to interactions with the smaller planets.
# - The smaller planets, representing the disk, exert gravitational forces on the primary planet, causing it to migrate inward.
# - This behavior aligns with the concept of planetary migration, where interactions with a protoplanetary disk or other bodies can alter a planet's orbit.
# - The inward migration of the primary planet is consistent with expectations for a massive planet interacting with a surrounding disk of smaller bodies.

# %% [markdown]
# ✅ **Question 2.13 (4 points):** Was this what you expected to see based on the concept of planetary migration? Explain why.

# %% [markdown]
# - The plot shows that the primary planet's orbital radius decreases over time.
# - This indicates that the primary planet is losing angular momentum, likely due to interactions with the smaller planets.
# - The smaller planets, representing the disk, exert gravitational forces on the primary planet, causing it to migrate inward.
# - This behavior is consistent with the concept of planetary migration, where interactions with a protoplanetary disk or other bodies can alter a planet's orbit.
# - The inward migration of the primary planet aligns with expectations for a massive planet interacting with a surrounding disk of smaller bodies.

# %% [markdown]
# ---
# ## &#128721; STOP
# **Pause to commit your changes to your Git repository! (1 points)**
#
# Take a moment to save your notebook, commit the changes to your Git repository using the commit message "**Committing Part 2**", no need to push the changes to GitHub yet, but you can if you want.
#
# ---
# If you like, you can upload this file to D2L for a record. Nevertheless, **we will grade the copy on GitHub**.

# %% [markdown]
# ---
# ---
# ## Post-assignment Survey
# Please fill out the post-assignment survey [**here**](https://forms.office.com/r/0DRDevWLJT).

# %% [markdown]
# &#169; Copyright 2024,  Department of Computational Mathematics, Science and Engineering at Michigan State University
